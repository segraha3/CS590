# %%
# Read in Import peanut_lines.csv
import os
import numpy as np
import pandas as pd

lines = pd.read_csv('C:\\Users\\segraha3\\Desktop\\CS590\\peanut_lines.csv', encoding='ISO-8859-1')

# %%
lines.head(25)
# Out:
#      NC_Accession                                          Parentage  \
# 0   ACI WT09-0761                                      ACI WT09-0761
# 1   ACI WT11-0351                                      ACI WT11-0351
# 2   ACI WT12-0226                                      ACI WT12-0226
# 3   ACI WT12-0419                                      ACI WT12-0419
# 4   ACI WT12-0420                                      ACI WT12-0420
# 5   ACI WT12-0433                                      ACI WT12-0433
# 6          Bailey                                 NC 12C*2 / N96076L
# 7       Bailey II  Bailey /4/ X07016, Bailey // X05027, Bailey / ...
# 8        Brantley                                           Brantley
# 9          CHAMPS                                             CHAMPS
# 10          Emery                              N03079FT*2 / Brantley
# 11  Florida Fancy                                      Florida Fancy
# 12     Florida-07                                         Florida-07
# 13     FloriGiant                                         FloriGiant
# 14     FloRun 107                                         FloRun 107
# 15     FloRun 157                                         FloRun 157
# 16     FloRun 331                                         FloRun 331
# 17  Georgia Green                                      Georgia Green
# 18    Georgia-06G                                        Georgia-06G
# 19    Georgia-07W                                        Georgia-07W
# 20    Georgia-09B                                        Georgia-09B
# 21    Georgia-11J                                        Georgia-11J
# 22    Georgia-12Y                                        Georgia-12Y
# 23        Gregory                                            Gregory
# 24       Harris 1                                           Harris 1
#
#                         Pedigree    FAG
# 0                            NaN  Check
# 1                            NaN  ol ol
# 2                            NaN  ol ol
# 3                            NaN  Check
# 4                            NaN  ol ol
# 5                            NaN  Check
# 6     BC1F1-06-01-S-03-S-05: F09    + +
# 7     BC3F1-02-01-S-02-S-02: F09  ol ol
# 8                            NaN  ol ol
# 9                            NaN    + +
# 10  BC1F1-03-01-01-02-02-01: F08  ol ol
# 11                           NaN  ol ol
# 12                           NaN  ol ol
# 13                           NaN    + +
# 14                           NaN  ol ol
# 15                           NaN  ol ol
# 16                           NaN  ol ol
# 17                           NaN    + +
# 18                           NaN    + +
# 19                           NaN    + +
# 20                           NaN  ol ol
# 21                           NaN  ol ol
# 22                           NaN    + +
# 23                           NaN    + +
# 24                           NaN  Check

# %%
#count lines with Bailey as parent
import re

bailey_count = []
for i in range(0,len(lines)):
    if re.search('Bailey',lines['Parentage'].iloc[i]):
        bailey_count.append(i)
    else:
        continue
    
len(bailey_count)
# Out:
# 82

# %%
def bailey(x):
    if re.search('Bailey', x):
        return 'Yes'
    else:
        return 'No'
    
lines['Bailey_Parent'] = lines['Parentage'].apply(bailey)
lines.head(10)
# Out:
#     NC_Accession                                          Parentage  \
# 0  ACI WT09-0761                                      ACI WT09-0761
# 1  ACI WT11-0351                                      ACI WT11-0351
# 2  ACI WT12-0226                                      ACI WT12-0226
# 3  ACI WT12-0419                                      ACI WT12-0419
# 4  ACI WT12-0420                                      ACI WT12-0420
# 5  ACI WT12-0433                                      ACI WT12-0433
# 6         Bailey                                 NC 12C*2 / N96076L
# 7      Bailey II  Bailey /4/ X07016, Bailey // X05027, Bailey / ...
# 8       Brantley                                           Brantley
# 9         CHAMPS                                             CHAMPS
#
#                      Pedigree    FAG Bailey_Parent
# 0                         NaN  Check            No
# 1                         NaN  ol ol            No
# 2                         NaN  ol ol            No
# 3                         NaN  Check            No
# 4                         NaN  ol ol            No
# 5                         NaN  Check            No
# 6  BC1F1-06-01-S-03-S-05: F09    + +            No
# 7  BC3F1-02-01-S-02-S-02: F09  ol ol           Yes
# 8                         NaN  ol ol            No
# 9                         NaN    + +            No

# %%
bailey_perc = round(len(lines[(lines['Bailey_Parent'] == 'Yes') & (lines['FAG'] == 'ol ol')]) / len(lines) * 100, 1)
print('%s%%'%(bailey_perc))
# Out:
# 16.1%

# %%
lines['Parentage'] = lines['Parentage'].str.replace('Bailey','N03081T')
lines.head(10)
# Out:
#     NC_Accession                                          Parentage  \
# 0  ACI WT09-0761                                      ACI WT09-0761
# 1  ACI WT11-0351                                      ACI WT11-0351
# 2  ACI WT12-0226                                      ACI WT12-0226
# 3  ACI WT12-0419                                      ACI WT12-0419
# 4  ACI WT12-0420                                      ACI WT12-0420
# 5  ACI WT12-0433                                      ACI WT12-0433
# 6         Bailey                                 NC 12C*2 / N96076L
# 7      Bailey II  N03081T /4/ X07016, N03081T // X05027, N03081T...
# 8       Brantley                                           Brantley
# 9         CHAMPS                                             CHAMPS
#
#                      Pedigree    FAG Bailey_Parent
# 0                         NaN  Check            No
# 1                         NaN  ol ol            No
# 2                         NaN  ol ol            No
# 3                         NaN  Check            No
# 4                         NaN  ol ol            No
# 5                         NaN  Check            No
# 6  BC1F1-06-01-S-03-S-05: F09    + +            No
# 7  BC3F1-02-01-S-02-S-02: F09  ol ol           Yes
# 8                         NaN  ol ol            No
# 9                         NaN    + +            No

# %%
yields = pd.read_csv('peanut_yield.txt', header=0, sep='\t')
peanut_db = pd.merge(lines, yields, on='NC_Accession', how='right')

# %%
peanut_db.head()
# Out:
#     NC_Accession      Parentage Pedigree    FAG Bailey_Parent  Year Location  \
# 0  ACI WT09-0761  ACI WT09-0761      NaN  Check            No  2014      LEW
# 1  ACI WT09-0761  ACI WT09-0761      NaN  Check            No  2014      RMT
# 2  ACI WT09-0761  ACI WT09-0761      NaN  Check            No  2014      WHI
# 3  ACI WT11-0351  ACI WT11-0351      NaN  ol ol            No  2015      LEW
# 4  ACI WT11-0351  ACI WT11-0351      NaN  ol ol            No  2015      RMT
#
#   Name                             Label  Plot_Yield  Yield
# 0  ATP  Advanced Testing Program - Yield         9.0   2733
# 1  ATP  Advanced Testing Program - Yield        10.2   3085
# 2  ATP  Advanced Testing Program - Yield        10.2   3085
# 3  ATP  Advanced Testing Program - Yield        15.3   4632
# 4  ATP  Advanced Testing Program - Yield        10.7   3226

# %%
peanut_db = peanut_db[(peanut_db['NC_Accession'] == 'Bailey') | (peanut_db['Bailey_Parent'] == 'Yes')]

# %%
Line = ['Bailey','Other']
Yield = [peanut_db[peanut_db['NC_Accession'] == 'Bailey']['Yield'].mean(), peanut_db[peanut_db['NC_Accession'] != 'Bailey']['Yield'].mean()]
df = pd.DataFrame(Yield, Line, columns=['Yield'])
df
# Out:
#               Yield
# Bailey  3562.153846
# Other   3713.964015
